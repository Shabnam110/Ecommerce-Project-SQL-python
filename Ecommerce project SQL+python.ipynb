# %%
import pandas as pd
import mysql.connector
import os

# List of CSV files and their corresponding table names
csv_files = [
    ('customers.csv', 'customers'),
    ('orders.csv', 'orders'),
    ('sellers.csv', 'sellers'),
    ('products.csv', 'products'),
    ('geolocation.csv', 'geolocation'),
    ('payments.csv', 'payments'),
    ('order_items.csv', 'order_items')# Added payments.csv for specific handling
]

# Connect to the MySQL database
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='Shab@1234',
    database='Ecommerce'
)
cursor = conn.cursor()

# Folder containing the CSV files
folder_path = '/home/shabnam/Desktop/E-commerce archive(8)'

def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Replace NaN with None to handle SQL NULL
    df = df.where(pd.notnull(df), None)
    
    # Debugging: Check for NaN values
    print(f"Processing {csv_file}")
    print(f"NaN values before replacement:\n{df.isnull().sum()}\n")

    # Clean column names
    df.columns = [col.replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]

    # Generate the CREATE TABLE statement with appropriate data types
    columns = ', '.join([f'`{col}` {get_sql_type(df[col].dtype)}' for col in df.columns])
    create_table_query = f'CREATE TABLE IF NOT EXISTS `{table_name}` ({columns})'
    cursor.execute(create_table_query)

    # Insert DataFrame data into the MySQL table
    for _, row in df.iterrows():
        # Convert row to tuple and handle NaN/None explicitly
        values = tuple(None if pd.isna(x) else x for x in row)
        sql = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({', '.join(['%s'] * len(row))})"
        cursor.execute(sql, values)

    # Commit the transaction for the current CSV file
    conn.commit()

# Close the connection
conn.close()
# Out:
# Processing customers.csv
# NaN values before replacement:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Processing orders.csv
# NaN values before replacement:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# Processing sellers.csv
# NaN values before replacement:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
#
# Processing products.csv
# NaN values before replacement:
# product_id                      0
# product category              610
# product_name_length           610
# product_description_length    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
#
# Processing geolocation.csv
# NaN values before replacement:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# Processing payments.csv
# NaN values before replacement:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# Processing order_items.csv
# NaN values before replacement:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in ./anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in ./anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/60/53/7468007a8f9d5b1f251b50039969a600e84114934d1369d6f7090e24369d/mysql_connector_python-9.0.0-cp311-cp311-manylinux_2_17_x86_64.whl.metadata
#   Downloading mysql_connector_python-9.0.0-cp311-cp311-manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Downloading mysql_connector_python-9.0.0-cp311-cp311-manylinux_2_17_x86_64.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in ./anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector

db =mysql.connector.connect(host = "localhost",
                           username ="root",
                           password ="Shab@1234",
                           database ="Ecommerce")

cur = db.cursor()

# %% [markdown]
# # List All unique Cities where customers are Located.

# %%
 query ="""select distinct customer_city from customers"""

cur.execute(query)

data = cur.fetchall()

df = pd.DataFrame(data)
df.head(5)
# Out:
#                        0
# 0                 franca
# 1  sao bernardo do campo
# 2              sao paulo
# 3        mogi das cruzes
# 4               campinas

# %% [markdown]
# # Count the number of orders plced in 2017

# %%
query ="""select count(order_id) from orders where year(order_purchase_timestamp) = 2017"""

cur.execute(query)

data = cur.fetchall()

'total orders placed in 2017 are',data[0][0]
# Out:
# ('total orders placed in 2017 are', 180404)

# %% [markdown]
# # Find the total sales per category.

# %%
query = """ select upper(products.product_category) category, 
round(sum(payments.payment_value),2) sales
from products join order_items 
on products.product_id = order_items.product_id
join payments 
on payments.order_id = order_items.order_id
group by category
"""

cur.execute(query)

data = cur.fetchall()

df = pd.DataFrame(data, columns = ["Category", "Sales"])
df
# Out:
#                        Category         Sales
# 0                     PERFUMERY  3.243127e+07
# 1          FURNITURE DECORATION  9.153129e+07
# 2                     TELEPHONY  3.116045e+07
# 3                BED TABLE BATH  1.096034e+08
# 4                    AUTOMOTIVE  5.454684e+07
# ..                          ...           ...
# 69               CDS MUSIC DVDS  7.676352e+04
# 70                   LA CUISINE  1.864659e+05
# 71  FASHION CHILDREN'S CLOTHING  5.028288e+04
# 72                     PC GAMER  1.391635e+05
# 73       INSURANCE AND SERVICES  2.076864e+04
#
# [74 rows x 2 columns]

# %%
#sql me aap real time analysis karte hoo and 
#Jupiter me aap visualize bhi kar sakte hai

# %% [markdown]
# # Calculate the percentage of orders that were paid in installments

# %%
query ="""select sum(case when payment_installments >=1 then 1
else 0 end)/count(*)*100 from payments"""

cur.execute(query)

data = cur.fetchall()
data
# Out:
# [(Decimal('99.9981'),)]

# %% [markdown]
# # Count the number of customers from each state.

# %%
import pandas as pd
query ="""select customer_state , count(customer_id)
from customers group by customer_state"""

cur.execute(query)

data = cur.fetchall()
df = pd.DataFrame(data,columns = ["state","customer_count"])

plt.bar(df['state'],['customer_count'])
plt.show()

# %%
query = """ select customer_state ,count(customer_id)
from customers group by customer_state
"""

cur.execute(query)

data = cur.fetchall()
df = pd.DataFrame(data, columns = ["state", "customer_count" ])
df = df.sort_values(by = "customer_count", ascending= False)

plt.figure(figsize = (8,3))
plt.bar(df["state"], df["customer_count"])
plt.xticks(rotation = 90)
plt.xlabel("states")
plt.ylabel("customer_count")
plt.title("Count of Customers by States")
plt.show()

# %% [markdown]
# # Intermediate level

# %% [markdown]
# # Calculate the number of orders per month in 2018.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector

db =mysql.connector.connect(host = "localhost",
                           username ="root",
                           password ="Shab@1234",
                           database ="Ecommerce")

cur = db.cursor()

# %%
query = """ select monthname(order_purchase_timestamp) months,count(order_id)
 order_count
 from orders where year(order_purchase_timestamp) = 2018
 group by months"""

cur.execute(query)

df = pd.DataFrame(data, columns = ["months", "order_count"])
o = ["January", "February","March","April","May","June","July","August","September","October"]

ax = sns.barplot(x = df["months"],y =  df["order_count"], data = df, order = o, color = "red")
plt.xticks(rotation = 45)
ax.bar_label(ax.containers[0])
plt.title("Count of Orders by Months is 2018")

plt.show()

# %% [markdown]
# # Find the average number of products per order, grouped by customer city.

# %%
query = """with count_per_order as 
(select orders.order_id, orders.customer_id, count(order_items.order_id) as oc
from orders join order_items
on orders.order_id = order_items.order_id
group by orders.order_id, orders.customer_id)

select customers.customer_city, round(avg(count_per_order.oc),2) average_orders
from customers join count_per_order
on customers.customer_id = count_per_order.customer_id
group by customers.customer_city order by average_orders desc
"""

cur.execute(query)

data = cur.fetchall()
#df = pd.DataFrame(data,columns = ["customer city", "average products/order"])
#df.head(10)
data
# Out:
# [('padre carvalho', Decimal('112.00')),
#  ('celso ramos', Decimal('104.00')),
#  ('datas', Decimal('96.00')),
#  ('candido godoi', Decimal('96.00')),
#  ('matias olimpio', Decimal('80.00')),
#  ('cidelandia', Decimal('64.00')),
#  ('curralinho', Decimal('64.00')),
#  ('picarra', Decimal('64.00')),
#  ('morro de sao paulo', Decimal('64.00')),
#  ('teixeira soares', Decimal('64.00')),
#  ('inconfidentes', Decimal('56.00')),
#  ('ipua', Decimal('52.00')),
#  ('alto paraiso de goias', Decimal('48.00')),
#  ('nova esperanca do sul', Decimal('48.00')),
#  ('capela', Decimal('48.00')),
#  ('pedregulho', Decimal('48.00')),
#  ('jose boiteux', Decimal('48.00')),
#  ('buriti', Decimal('48.00')),
#  ('ouvidor', Decimal('48.00')),
#  ('pacuja', Decimal('48.00')),
#  ('brasileia', Decimal('48.00')),
#  ('ubata', Decimal('48.00')),
#  ('chapadao do lageado', Decimal('48.00')),
#  ('ubajara', Decimal('42.67')),
#  ('colonia castrolanda', Decimal('42.67')),
#  ('maracana', Decimal('40.00')),
#  ('sao miguel dos campos', Decimal('40.00')),
#  ('colonia jordaozinho', Decimal('40.00')),
#  ('formosa do rio preto', Decimal('37.33')),
#  ('cicero dantas', Decimal('36.80')),
#  ('capitolio', Decimal('35.20')),
#  ('sao jorge do ivai', Decimal('32.00')),
#  ('bonfinopolis', Decimal('32.00')),
#  ('santo antonio do caiua', Decimal('32.00')),
#  ('aguas vermelhas', Decimal('32.00')),
#  ('antonina do norte', Decimal('32.00')),
#  ('espinosa', Decimal('32.00')),
#  ('areias', Decimal('32.00')),
#  ('flores', Decimal('32.00')),
#  ('pauliceia', Decimal('32.00')),
#  ('nova hartz', Decimal('32.00')),
#  ('itarana', Decimal('32.00')),
#  ('nova alvorada do sul', Decimal('32.00')),
#  ('capitao eneas', Decimal('32.00')),
#  ('conceicao da aparecida', Decimal('32.00')),
#  ('candido mendes', Decimal('32.00')),
#  ('macieira', Decimal('32.00')),
#  ('passagem franca', Decimal('32.00')),
#  ('alexandrita', Decimal('32.00')),
#  ('carnaiba do sertao', Decimal('32.00')),
#  ('pardinho', Decimal('32.00')),
#  ('nova ipixuna', Decimal('32.00')),
#  ('monte belo do sul', Decimal('32.00')),
#  ('sao miguel do anta', Decimal('32.00')),
#  ('belo oriente', Decimal('32.00')),
#  ('uirauna', Decimal('32.00')),
#  ('jandaia', Decimal('32.00')),
#  ('altaneira', Decimal('32.00')),
#  ('cambara do sul', Decimal('32.00')),
#  ('sao felix do araguaia', Decimal('32.00')),
#  ('morro agudo', Decimal('32.00')),
#  ('santo antonio', Decimal('32.00')),
#  ('dionisio cerqueira', Decimal('32.00')),
#  ('sitio novo do tocantins', Decimal('32.00')),
#  ('doutor ulysses', Decimal('32.00')),
#  ('macaubal', Decimal('32.00')),
#  ('segredo', Decimal('32.00')),
#  ('ipueiras', Decimal('32.00')),
#  ('populina', Decimal('32.00')),
#  ('pocoes de paineiras', Decimal('32.00')),
#  ('almas', Decimal('32.00')),
#  ('lencois', Decimal('32.00')),
#  ('mato verde', Decimal('32.00')),
#  ('alcantara', Decimal('32.00')),
#  ('senador cortes', Decimal('32.00')),
#  ('passira', Decimal('32.00')),
#  ('tiradentes', Decimal('32.00')),
#  ('itajuipe', Decimal('32.00')),
#  ('nova olinda', Decimal('32.00')),
#  ('princesa isabel', Decimal('32.00')),
#  ('senhora de oliveira', Decimal('32.00')),
#  ('pains', Decimal('32.00')),
#  ('sao geraldo da piedade', Decimal('32.00')),
#  ('candoi', Decimal('32.00')),
#  ('solanea', Decimal('32.00')),
#  ('castelo do piaui', Decimal('32.00')),
#  ('itororo', Decimal('32.00')),
#  ('agua doce', Decimal('32.00')),
#  ('arneiroz', Decimal('32.00')),
#  ("alvorada d'oeste", Decimal('32.00')),
#  ('paula freitas', Decimal('32.00')),
#  ('jaboticatubas', Decimal('32.00')),
#  ('itacoatiara', Decimal('32.00')),
#  ('corrego danta', Decimal('32.00')),
#  ('curvelandia', Decimal('32.00')),
#  ('campo alegre do fidalgo', Decimal('32.00')),
#  ('campo florido', Decimal('32.00')),
#  ('pau brasil', Decimal('32.00')),
#  ('frei lagonegro', Decimal('32.00')),
#  ('lucianopolis', Decimal('32.00')),
#  ('anage', Decimal('32.00')),
#  ('novo itacolomi', Decimal('32.00')),
#  ('belmonte', Decimal('32.00')),
#  ('morro grande', Decimal('32.00')),
#  ('tres irmaos', Decimal('32.00')),
#  ('poco redondo', Decimal('32.00')),
#  ('abdon batista', Decimal('32.00')),
#  ('bandeira do sul', Decimal('32.00')),
#  ('ouro', Decimal('32.00')),
#  ('ponto novo', Decimal('32.00')),
#  ('rio doce', Decimal('32.00')),
#  ('cerro negro', Decimal('32.00')),
#  ('sao felix do coribe', Decimal('32.00')),
#  ('redencao do gurgueia', Decimal('32.00')),
#  ('engenheiro balduino', Decimal('32.00')),
#  ('mucurici', Decimal('32.00')),
#  ('passo de camaragibe', Decimal('32.00')),
#  ('gloria de dourados', Decimal('32.00')),
#  ('coronel murta', Decimal('32.00')),
#  ('campo magro', Decimal('32.00')),
#  ('silveira martins', Decimal('32.00')),
#  ('sao sebastiao do rio verde', Decimal('32.00')),
#  ('ibiracu', Decimal('32.00')),
#  ('vargem grande do rio pardo', Decimal('32.00')),
#  ('vitoria das missoes', Decimal('32.00')),
#  ('marilac', Decimal('32.00')),
#  ('capitao', Decimal('32.00')),
#  ('planaltino', Decimal('32.00')),
#  ('guairaca', Decimal('32.00')),
#  ('aguai', Decimal('30.40')),
#  ('itaqui', Decimal('30.22')),
#  ('ronda alta', Decimal('29.33')),
#  ('itajobi', Decimal('28.80')),
#  ('alto boa vista', Decimal('28.80')),
#  ('taiuva', Decimal('28.80')),
#  ('carmo do rio claro', Decimal('28.44')),
#  ('irece', Decimal('28.31')),
#  ('ipiau', Decimal('28.00')),
#  ('saudades', Decimal('28.00')),
#  ('conservatoria', Decimal('28.00')),
#  ('salto do lontra', Decimal('28.00')),
#  ('taguatinga', Decimal('27.43')),
#  ('aparecida do taboado', Decimal('27.43')),
#  ('malacacheta', Decimal('27.43')),
#  ('jumirim', Decimal('26.67')),
#  ('japira', Decimal('26.67')),
#  ('sertao', Decimal('26.67')),
#  ('mamanguape', Decimal('26.67')),
#  ('pedrinopolis', Decimal('26.67')),
#  ('quixabeira', Decimal('26.67')),
#  ('bofete', Decimal('26.67')),
#  ('capao do cipo', Decimal('26.67')),
#  ('clevelandia', Decimal('26.67')),
#  ('silveiras', Decimal('26.67')),
#  ('delfinopolis', Decimal('26.67')),
#  ('pedralva', Decimal('26.67')),
#  ('itaju', Decimal('26.67')),
#  ('upanema', Decimal('26.67')),
#  ('dom pedro', Decimal('26.67')),
#  ('massaranduba', Decimal('26.67')),
#  ('itarantim', Decimal('26.67')),
#  ('andrelandia', Decimal('26.67')),
#  ('janauba', Decimal('26.35')),
#  ('sao joao nepomuceno', Decimal('26.29')),
#  ('uniao da vitoria', Decimal('25.93')),
#  ('ariquemes', Decimal('25.85')),
#  ('eusebio', Decimal('25.85')),
#  ('sacramento', Decimal('25.85')),
#  ('monte belo', Decimal('25.60')),
#  ('cidade gaucha', Decimal('25.60')),
#  ('japuiba', Decimal('25.60')),
#  ('japura', Decimal('25.60')),
#  ('miracatu', Decimal('25.60')),
#  ('cassilandia', Decimal('25.60')),
#  ('campos novos', Decimal('25.14')),
#  ('santa cecilia', Decimal('25.14')),
#  ('laguna', Decimal('25.14')),
#  ('cerro largo', Decimal('25.14')),
#  ('sao raimundo nonato', Decimal('25.14')),
#  ('guapore', Decimal('24.89')),
#  ('buritizeiro', Decimal('24.89')),
#  ('macaubas', Decimal('24.89')),
#  ("herval d'oeste", Decimal('24.89')),
#  ('raposos', Decimal('24.73')),
#  ('paty do alferes', Decimal('24.62')),
#  ('rio do antonio', Decimal('24.00')),
#  ('itabaianinha', Decimal('24.00')),
#  ('santa clara do sul', Decimal('24.00')),
#  ('cafeara', Decimal('24.00')),
#  ('jambeiro', Decimal('24.00')),
#  ('juvenilia', Decimal('24.00')),
#  ('rosario do sul', Decimal('24.00')),
#  ('david canabarro', Decimal('24.00')),
#  ('balsamo', Decimal('24.00')),
#  ('sao goncalo do rio abaixo', Decimal('24.00')),
#  ('claudia', Decimal('24.00')),
#  ('cocalinho', Decimal('24.00')),
#  ('campo novo do parecis', Decimal('24.00')),
#  ('echapora', Decimal('24.00')),
#  ('araputanga', Decimal('24.00')),
#  ('paranaita', Decimal('24.00')),
#  ('portalegre', Decimal('24.00')),
#  ('tupancireta', Decimal('24.00')),
#  ('wenceslau braz', Decimal('24.00')),
#  ('luisburgo', Decimal('24.00')),
#  ('trancoso', Decimal('24.00')),
#  ('vila nelita', Decimal('24.00')),
#  ('guarai', Decimal('24.00')),
#  ('limeira do oeste', Decimal('24.00')),
#  ('rio do campo', Decimal('24.00')),
#  ('amapora', Decimal('24.00')),
#  ('satubinha', Decimal('24.00')),
#  ('espirito santo do turvo', Decimal('24.00')),
#  ('virginopolis', Decimal('24.00')),
#  ('benedito novo', Decimal('24.00')),
#  ('paraguacu', Decimal('24.00')),
#  ('santa cruz de goias', Decimal('24.00')),
#  ('caibate', Decimal('24.00')),
#  ('gaucha do norte', Decimal('24.00')),
#  ('juatuba', Decimal('24.00')),
#  ('tamarana', Decimal('24.00')),
#  ('silva jardim', Decimal('24.00')),
#  ('sao sebastiao do alto', Decimal('24.00')),
#  ('milha', Decimal('24.00')),
#  ('urania', Decimal('24.00')),
#  ('correntina', Decimal('24.00')),
#  ('itueta', Decimal('24.00')),
#  ('cariri do tocantins', Decimal('24.00')),
#  ('jandaia do sul', Decimal('24.00')),
#  ('careacu', Decimal('24.00')),
#  ('rodeio bonito', Decimal('24.00')),
#  ('conceicao da feira', Decimal('24.00')),
#  ('ribeirao vermelho', Decimal('24.00')),
#  ('senador guiomard', Decimal('24.00')),
#  ('colonia leopoldina', Decimal('24.00')),
#  ('macatuba', Decimal('24.00')),
#  ('diogo de vasconcelos', Decimal('24.00')),
#  ('catu de abrantes', Decimal('24.00')),
#  ('pejucara', Decimal('24.00')),
#  ('alto horizonte', Decimal('24.00')),
#  ('santa helena de minas', Decimal('24.00')),
#  ('cachoeira da prata', Decimal('24.00')),
#  ('boninal', Decimal('24.00')),
#  ('corrente', Decimal('24.00')),
#  ('uruoca', Decimal('24.00')),
#  ('trairi', Decimal('24.00')),
#  ('santana do serido', Decimal('24.00')),
#  ('campina da lagoa', Decimal('24.00')),
#  ('julio mesquita', Decimal('24.00')),
#  ('sapeacu', Decimal('24.00')),
#  ('alvares florence', Decimal('24.00')),
#  ('mairi', Decimal('24.00')),
#  ('miranorte', Decimal('24.00')),
#  ('cambira', Decimal('24.00')),
#  ('senador amaral', Decimal('24.00')),
#  ('mata grande', Decimal('24.00')),
#  ('arenapolis', Decimal('24.00')),
#  ('mato leitao', Decimal('24.00')),
#  ('delmiro gouveia', Decimal('24.00')),
#  ('borrazopolis', Decimal('24.00')),
#  ('urandi', Decimal('24.00')),
#  ('arembepe', Decimal('24.00')),
#  ('itambaraca', Decimal('24.00')),
#  ('paranatinga', Decimal('24.00')),
#  ('sao paulo das missoes', Decimal('24.00')),
#  ('bento de abreu', Decimal('24.00')),
#  ('alianca do tocantins', Decimal('24.00')),
#  ('laranjal do jari', Decimal('24.00')),
#  ('inimutaba', Decimal('24.00')),
#  ('vazante', Decimal('24.00')),
#  ('santa monica', Decimal('24.00')),
#  ('sao joao da mata', Decimal('24.00')),
#  ('mondai', Decimal('24.00')),
#  ('piata', Decimal('24.00')),
#  ('mercedes', Decimal('24.00')),
#  ('dormentes', Decimal('24.00')),
#  ('campo novo', Decimal('24.00')),
#  ('tabuleiro', Decimal('24.00')),
#  ('iguaracu', Decimal('24.00')),
#  ('itapetim', Decimal('24.00')),
#  ('santa mercedes', Decimal('24.00')),
#  ('monte alegre', Decimal('24.00')),
#  ('alto alegre do iguacu', Decimal('24.00')),
#  ('santana dos montes', Decimal('24.00')),
#  ('camocim de sao felix', Decimal('24.00')),
#  ('bom jesus das selvas', Decimal('24.00')),
#  ('rondon', Decimal('24.00')),
#  ('venda nova do imigrante', Decimal('23.47')),
#  ('barra de sao joao', Decimal('23.38')),
#  ('camaqua', Decimal('23.38')),
#  ('faxinal dos guedes', Decimal('23.27')),
#  ('peruibe', Decimal('23.27')),
#  ('santana do livramento', Decimal('23.20')),
#  ('veranopolis', Decimal('23.11')),
#  ('rondon do para', Decimal('23.11')),
#  ('ouro fino', Decimal('23.00')),
#  ('rubiataba', Decimal('22.86')),
#  ('bayeux', Decimal('22.86')),
#  ('tres cachoeiras', Decimal('22.86')),
#  ('barra do corda', Decimal('22.86')),
#  ('taquaritinga do norte', Decimal('22.86')),
#  ('neropolis', Decimal('22.86')),
#  ('pires do rio', Decimal('22.67')),
#  ('rio verde', Decimal('22.65')),
#  ('pompeia', Decimal('22.59')),
#  ('dracena', Decimal('22.52')),
#  ('senges', Decimal('22.40')),
#  ('guaracai', Decimal('22.40')),
#  ('moreno', Decimal('22.40')),
#  ('barra do garcas', Decimal('22.40')),
#  ('gaspar', Decimal('22.40')),
#  ('cacapava do sul', Decimal('22.40')),
#  ('porto xavier', Decimal('22.40')),
#  ('estancia velha', Decimal('22.40')),
#  ('paulo de faria', Decimal('22.40')),
#  ('sao miguel do araguaia', Decimal('22.40')),
#  ('novo progresso', Decimal('22.40')),
#  ('cambara', Decimal('22.40')),
#  ('brodowski', Decimal('22.40')),
#  ('sao benedito', Decimal('22.40')),
#  ('antonio prado', Decimal('22.40')),
#  ('saltinho', Decimal('22.40')),
#  ('ribeirao claro', Decimal('22.40')),
#  ('dom feliciano', Decimal('22.40')),
#  ('paramirim', Decimal('22.40')),
#  ('ourilandia do norte', Decimal('22.40')),
#  ('sooretama', Decimal('22.40')),
#  ('itarare', Decimal('22.29')),
#  ('piraju', Decimal('22.22')),
#  ('viradouro', Decimal('22.22')),
#  ('itupeva', Decimal('22.18')),
#  ('santana', Decimal('22.15')),
#  ('sao sebastiao do cai', Decimal('22.15')),
#  ('baixo guandu', Decimal('22.00')),
#  ('ibia', Decimal('22.00')),
#  ('itamarandiba', Decimal('22.00')),
#  ('itaiopolis', Decimal('22.00')),
#  ('bom jardim de minas', Decimal('22.00')),
#  ('maracai', Decimal('22.00')),
#  ('nova esperanca', Decimal('22.00')),
#  ('cordeiropolis', Decimal('22.00')),
#  ('codo', Decimal('22.00')),
#  ('teotonio vilela', Decimal('22.00')),
#  ('iguaba grande', Decimal('21.89')),
#  ('gravata', Decimal('21.82')),
#  ('embu', Decimal('21.82')),
#  ('castro', Decimal('21.82')),
#  ('barroso', Decimal('21.82')),
#  ('presidente venceslau', Decimal('21.76')),
#  ('santa rosa de viterbo', Decimal('21.71')),
#  ('garopaba', Decimal('21.57')),
#  ('arraial do cabo', Decimal('21.52')),
#  ('itanhaem', Decimal('21.47')),
#  ('mario campos', Decimal('21.33')),
#  ('vianopolis', Decimal('21.33')),
#  ('mata verde', Decimal('21.33')),
#  ('sao sepe', Decimal('21.33')),
#  ('icara', Decimal('21.33')),
#  ('carai', Decimal('21.33')),
#  ('nova monte verde', Decimal('21.33')),
#  ('sao joao do piaui', Decimal('21.33')),
#  ('gaurama', Decimal('21.33')),
#  ('alcinopolis', Decimal('21.33')),
#  ('sao ludgero', Decimal('21.33')),
#  ('sao tomas de aquino', Decimal('21.33')),
#  ('francisco badaro', Decimal('21.33')),
#  ('montalvania', Decimal('21.33')),
#  ('ipira', Decimal('21.33')),
#  ('salgado filho', Decimal('21.33')),
#  ('maripa', Decimal('21.33')),
#  ('saloa', Decimal('21.33')),
#  ('piumhi', Decimal('21.33')),
#  ('ituacu', Decimal('21.33')),
#  ('itaituba', Decimal('21.33')),
#  ('angulo', Decimal('21.33')),
#  ('ipubi', Decimal('21.33')),
#  ('sao mateus do sul', Decimal('21.33')),
#  ('urubici', Decimal('21.33')),
#  ('santa maria de jetiba', Decimal('21.33')),
#  ('inaciolandia', Decimal('21.33')),
#  ('paraibano', Decimal('21.33')),
#  ('barra do turvo', Decimal('21.33')),
#  ('joaquim tavora', Decimal('21.33')),
#  ('santana do araguaia', Decimal('21.33')),
#  ('goncalves', Decimal('21.33')),
#  ('araci', Decimal('21.33')),
#  ('mandaguari', Decimal('21.33')),
#  ('reserva', Decimal('21.33')),
#  ('morrinhos', Decimal('21.33')),
#  ('ivinhema', Decimal('21.33')),
#  ('goianinha', Decimal('21.33')),
#  ('barbosa ferraz', Decimal('21.33')),
#  ('nova canaa do norte', Decimal('21.33')),
#  ('pedreiras', Decimal('21.33')),
#  ('pirajui', Decimal('21.33')),
#  ('california da barra', Decimal('21.33')),
#  ('hidreletrica tucurui', Decimal('21.33')),
#  ('bananal', Decimal('21.33')),
#  ('realeza', Decimal('21.33')),
#  ('aguas belas', Decimal('21.33')),
#  ('rio real', Decimal('21.33')),
#  ('chapadinha', Decimal('21.33')),
#  ('piedade do rio grande', Decimal('21.33')),
#  ('arroio grande', Decimal('21.33')),
#  ('janiopolis', Decimal('21.33')),
#  ('itambacuri', Decimal('21.33')),
#  ('carambei', Decimal('21.33')),
#  ('itubera', Decimal('21.33')),
#  ('barros cassal', Decimal('21.33')),
#  ('ribeirao do sul', Decimal('21.33')),
#  ('cosmorama', Decimal('21.33')),
#  ('florestopolis', Decimal('21.33')),
#  ('carius', Decimal('21.33')),
#  ('estancia', Decimal('21.33')),
#  ('itinga', Decimal('21.33')),
#  ('paulistana', Decimal('21.33')),
#  ('dom basilio', Decimal('21.33')),
#  ('buritama', Decimal('21.33')),
#  ('sao mateus do maranhao', Decimal('21.33')),
#  ('sao jose da bela vista', Decimal('21.33')),
#  ('morro reuter', Decimal('21.33')),
#  ('apiai', Decimal('21.33')),
#  ('morada nova de minas', Decimal('21.33')),
#  ('rio paranaiba', Decimal('21.33')),
#  ('raposo', Decimal('21.33')),
#  ('amambai', Decimal('21.33')),
#  ('oriente', Decimal('21.33')),
#  ('sanharo', Decimal('21.33')),
#  ('itatim', Decimal('21.33')),
#  ('ubaporanga', Decimal('21.33')),
#  ('uruana', Decimal('21.33')),
#  ('cristais', Decimal('21.33')),
#  ('entre-ijuis', Decimal('21.33')),
#  ('vera', Decimal('21.33')),
#  ('ritapolis', Decimal('21.33')),
#  ('nova alvorada', Decimal('21.33')),
#  ('cruzalia', Decimal('21.33')),
#  ('fatima', Decimal('21.33')),
#  ('pocinhos', Decimal('21.33')),
#  ('tupi paulista', Decimal('21.33')),
#  ('setubinha', Decimal('21.33')),
#  ('cacule', Decimal('21.33')),
#  ('santana do mundau', Decimal('21.33')),
#  ('marco', Decimal('21.33')),
#  ('sao goncalo do para', Decimal('21.33')),
#  ('mirinzal', Decimal('21.33')),
#  ('acu', Decimal('21.33')),
#  ('vila rica', Decimal('21.33')),
#  ('jaguariuna', Decimal('21.25')),
#  ('japeri', Decimal('21.18')),
#  ('brumado', Decimal('21.09')),
#  ('senhor do bonfim', Decimal('21.05')),
#  ('osvaldo cruz', Decimal('21.00')),
#  ('forquilhinha', Decimal('20.92')),
#  ('capanema', Decimal('20.92')),
#  ('ibirama', Decimal('20.92')),
#  ('imbe', Decimal('20.92')),
#  ('sao sebastiao', Decimal('20.80')),
#  ('serra talhada', Decimal('20.80')),
#  ('igarape', Decimal('20.80')),
#  ('regente feijo', Decimal('20.80')),
#  ('guara', Decimal('20.80')),
#  ('itamonte', Decimal('20.80')),
#  ('penapolis', Decimal('20.76')),
#  ('santo anastacio', Decimal('20.71')),
#  ('santa cruz do sul', Decimal('20.65')),
#  ('arroio do sal', Decimal('20.57')),
#  ('espumoso', Decimal('20.57')),
#  ('pinhalzinho', Decimal('20.57')),
#  ('ipaussu', Decimal('20.57')),
#  ('dores do indaia', Decimal('20.57')),
#  ('orlandia', Decimal('20.57')),
#  ('luis antonio', Decimal('20.57')),
#  ('acreuna', Decimal('20.57')),
#  ('lapa', Decimal('20.57')),
#  ('sao jeronimo', Decimal('20.57')),
#  ('santa albertina', Decimal('20.57')),
#  ('itaporanga', Decimal('20.57')),
#  ('sao gabriel do oeste', Decimal('20.57')),
#  ('nao-me-toque', Decimal('20.57')),
#  ('ipanema', Decimal('20.57')),
#  ('ibotirama', Decimal('20.57')),
#  ('morro do chapeu', Decimal('20.57')),
#  ('marmeleiro', Decimal('20.57')),
#  ('matupa', Decimal('20.57')),
#  ('campanha', Decimal('20.57')),
#  ('eldorado', Decimal('20.57')),
#  ('dianopolis', Decimal('20.57')),
#  ('barra da estiva', Decimal('20.57')),
#  ('uba', Decimal('20.53')),
#  ('concordia', Decimal('20.48')),
#  ('bonfim paulista', Decimal('20.44')),
#  ('ponta pora', Decimal('20.44')),
#  ('itumbiara', Decimal('20.44')),
#  ('tiete', Decimal('20.44')),
#  ('goianesia', Decimal('20.44')),
#  ('porto seguro', Decimal('20.40')),
#  ('treze tilias', Decimal('20.36')),
#  ('astolfo dutra', Decimal('20.36')),
#  ('sinop', Decimal('20.36')),
#  ('mantena', Decimal('20.36')),
#  ('araquari', Decimal('20.36')),
#  ('abaetetuba', Decimal('20.36')),
#  ('bacabal', Decimal('20.36')),
#  ('salinas', Decimal('20.36')),
#  ('nova andradina', Decimal('20.36')),
#  ('abreu e lima', Decimal('20.36')),
#  ('andira', Decimal('20.36')),
#  ('apucarana', Decimal('20.31')),
#  ('santiago', Decimal('20.31')),
#  ('ijui', Decimal('20.31')),
#  ('brumadinho', Decimal('20.31')),
#  ('pocos de caldas', Decimal('20.30')),
#  ('tres coracoes', Decimal('20.29')),
#  ('pirai', Decimal('20.27')),
#  ('junqueiropolis', Decimal('20.27')),
#  ('bariri', Decimal('20.27')),
#  ('caruaru', Decimal('20.25')),
#  ('mesquita', Decimal('20.21')),
#  ('corumba', Decimal('20.15')),
#  ('rolandia', Decimal('20.15')),
#  ('parauapebas', Decimal('20.15')),
#  ('angra dos reis', Decimal('20.14')),
#  ('teofilo otoni', Decimal('20.05')),
#  ('franca', Decimal('20.03')),
#  ('pedro leopoldo', Decimal('20.00')),
#  ('alta floresta', Decimal('20.00')),
#  ('agua doce do norte', Decimal('20.00')),
#  ('itaipava', Decimal('20.00')),
#  ('bilac', Decimal('20.00')),
#  ('itapaci', Decimal('20.00')),
#  ('lucas do rio verde', Decimal('20.00')),
#  ('perdizes', Decimal('20.00')),
#  ('sorriso', Decimal('20.00')),
#  ('nova bassano', Decimal('20.00')),
#  ('aperibe', Decimal('20.00')),
#  ('sao luis de montes belos', Decimal('20.00')),
#  ('rio bananal', Decimal('20.00')),
#  ('ipiabas', Decimal('20.00')),
#  ('curitibanos', Decimal('20.00')),
#  ('conceicao das pedras', Decimal('20.00')),
#  ('jaguarao', Decimal('20.00')),
#  ('cravinhos', Decimal('20.00')),
#  ('alto do rodrigues', Decimal('20.00')),
#  ('cacequi', Decimal('20.00')),
#  ('sao joaquim de bicas', Decimal('20.00')),
#  ('riacho de santana', Decimal('20.00')),
#  ('jacare', Decimal('20.00')),
#  ('candido de abreu', Decimal('20.00')),
#  ('capao do leao', Decimal('20.00')),
#  ('porciuncula', Decimal('20.00')),
#  ('martinopolis', Decimal('20.00')),
#  ('dores do rio preto', Decimal('20.00')),
#  ('santo antonio das missoes', Decimal('20.00')),
#  ('muqui', Decimal('20.00')),
#  ('itabaiana', Decimal('20.00')),
#  ('sao lourenco da serra', Decimal('20.00')),
#  ('manoel ribas', Decimal('20.00')),
#  ('bom jesus do itabapoana', Decimal('20.00')),
#  ('cacu', Decimal('20.00')),
#  ('conceicao do mato dentro', Decimal('20.00')),
#  ('munhoz', Decimal('20.00')),
#  ('santa vitoria do palmar', Decimal('20.00')),
#  ('navirai', Decimal('20.00')),
#  ('campo alegre', Decimal('20.00')),
#  ('santo antonio do amparo', Decimal('20.00')),
#  ('sao gotardo', Decimal('20.00')),
#  ('lambari', Decimal('20.00')),
#  ('gouveia', Decimal('20.00')),
#  ('baependi', Decimal('20.00')),
#  ('ibipora', Decimal('20.00')),
#  ('catuipe', Decimal('20.00')),
#  ('urucui', Decimal('20.00')),
#  ('imbituva', Decimal('20.00')),
#  ('sao geraldo', Decimal('20.00')),
#  ('maristela', Decimal('20.00')),
#  ('pongai', Decimal('20.00')),
#  ('guadalupe', Decimal('20.00')),
#  ('rio do pires', Decimal('20.00')),
#  ('imbuia', Decimal('20.00')),
#  ('colider', Decimal('20.00')),
#  ('campos sales', Decimal('20.00')),
#  ('condor', Decimal('20.00')),
#  ('vila valerio', Decimal('20.00')),
#  ('fervedouro', Decimal('20.00')),
#  ('eneas marques', Decimal('20.00')),
#  ('salto do jacui', Decimal('20.00')),
#  ('papanduva', Decimal('20.00')),
#  ('indiara', Decimal('20.00')),
#  ('papagaios', Decimal('20.00')),
#  ('araripina', Decimal('20.00')),
#  ('santa maria de itabira', Decimal('20.00')),
#  ('monte alegre de minas', Decimal('20.00')),
#  ('candelaria', Decimal('20.00')),
#  ('figueira', Decimal('20.00')),
#  ('irapua', Decimal('20.00')),
#  ('minas novas', Decimal('20.00')),
#  ('colinas', Decimal('20.00')),
#  ('arandu', Decimal('20.00')),
#  ('arealva', Decimal('20.00')),
#  ('sao domingos do prata', Decimal('20.00')),
#  ('travessao', Decimal('20.00')),
#  ('parambu', Decimal('20.00')),
#  ('sao miguel', Decimal('20.00')),
#  ('sanclerlandia', Decimal('20.00')),
#  ('sao miguel do guapore', Decimal('20.00')),
#  ('sertanopolis', Decimal('20.00')),
#  ('varjota', Decimal('20.00')),
#  ('santo antonio do jacinto', Decimal('20.00')),
#  ('iapu', Decimal('20.00')),
#  ('nova bandeirantes', Decimal('20.00')),
#  ('sete barras', Decimal('20.00')),
#  ('jaragua do sul', Decimal('19.96')),
#  ('colatina', Decimal('19.94')),
#  ('pato branco', Decimal('19.92')),
#  ('vassouras', Decimal('19.89')),
#  ('seropedica', Decimal('19.88')),
#  ('caceres', Decimal('19.84')),
#  ('embu-guacu', Decimal('19.83')),
#  ('paranavai', Decimal('19.83')),
#  ('caraguatatuba', Decimal('19.82')),
#  ('sao francisco do sul', Decimal('19.76')),
#  ('catalao', Decimal('19.76')),
#  ('torres', Decimal('19.76')),
#  ('alfenas', Decimal('19.72')),
#  ('maracaju', Decimal('19.69')),
#  ('matias barbosa', Decimal('19.69')),
#  ('santa cruz do capibaribe', Decimal('19.69')),
#  ('tupaciguara', Decimal('19.69')),
#  ('camacari', Decimal('19.67')),
#  ('colombo', Decimal('19.67')),
#  ('rio do sul', Decimal('19.66')),
#  ('criciuma', Decimal('19.65')),
#  ('santo antonio de padua', Decimal('19.61')),
#  ('sapucaia do sul', Decimal('19.60')),
#  ('chapeco', Decimal('19.57')),
#  ('vinhedo', Decimal('19.57')),
#  ('queimados', Decimal('19.56')),
#  ('paracatu', Decimal('19.56')),
#  ('dourado', Decimal('19.56')),
#  ('santa rita do passa quatro', Decimal('19.56')),
#  ('icem', Decimal('19.56')),
#  ('balneario picarras', Decimal('19.56')),
#  ('sobradinho', Decimal('19.56')),
#  ('piranguinho', Decimal('19.56')),
#  ('mirai', Decimal('19.56')),
#  ('bom jesus da lapa', Decimal('19.56')),
#  ('porto ferreira', Decimal('19.56')),
#  ('potirendaba', Decimal('19.56')),
#  ('pedro de toledo', Decimal('19.56')),
#  ('matinhos', Decimal('19.56')),
#  ('sao joaquim', Decimal('19.56')),
#  ('russas', Decimal('19.56')),
#  ('pomerode', Decimal('19.56')),
#  ('ourinhos', Decimal('19.53')),
#  ('itapetininga', Decimal('19.53')),
#  ('artur nogueira', Decimal('19.51')),
#  ('manhuacu', Decimal('19.50')),
#  ('birigui', Decimal('19.49')),
#  ('ituiutaba', Decimal('19.49')),
#  ('patrocinio', Decimal('19.48')),
#  ('santo angelo', Decimal('19.48')),
#  ('paranagua', Decimal('19.47')),
#  ('divinopolis', Decimal('19.44')),
#  ('cruzeiro', Decimal('19.43')),
#  ('serra negra', Decimal('19.43')),
#  ('triunfo', Decimal('19.43')),
#  ('piraquara', Decimal('19.43')),
#  ('teutonia', Decimal('19.43')),
#  ('novo hamburgo', Decimal('19.41')),
#  ('araras', Decimal('19.40')),
#  ('socorro', Decimal('19.37')),
#  ('paraty', Decimal('19.37')),
#  ('monte azul paulista', Decimal('19.37')),
#  ('cascavel', Decimal('19.35')),
#  ('guaira', Decimal('19.35')),
#  ('ilheus', Decimal('19.33')),
#  ('xanxere', Decimal('19.31')),
#  ('votuporanga', Decimal('19.30')),
#  ('sao joaquim da barra', Decimal('19.29')),
#  ('arapongas', Decimal('19.29')),
#  ('maracanau', Decimal('19.29')),
#  ('araucaria', Decimal('19.26')),
#  ('assis', Decimal('19.24')),
#  ('itabira', Decimal('19.24')),
#  ('palhoca', Decimal('19.23')),
#  ('palmas', Decimal('19.23')),
#  ('ribeirao das neves', Decimal('19.23')),
#  ('rafard', Decimal('19.20')),
#  ('coromandel', Decimal('19.20')),
#  ('arapora', Decimal('19.20')),
#  ('vargem bonita', Decimal('19.20')),
#  ('monte aprazivel', Decimal('19.20')),
#  ('pradopolis', Decimal('19.20')),
#  ('sao miguel do oeste', Decimal('19.20')),
#  ('buenopolis', Decimal('19.20')),
#  ('santa ines', Decimal('19.20')),
#  ('dom eliseu', Decimal('19.20')),
#  ('taio', Decimal('19.20')),
#  ('mineiros', Decimal('19.20')),
#  ('capitao leonidas marques', Decimal('19.20')),
#  ('santo antonio do descoberto', Decimal('19.20')),
#  ('bananeiras', Decimal('19.20')),
#  ('jesuania', Decimal('19.20')),
#  ('agua branca', Decimal('19.20')),
#  ('aurora', Decimal('19.20')),
#  ('sapiranga', Decimal('19.20')),
#  ('urupes', Decimal('19.20')),
#  ('quatis', Decimal('19.20')),
#  ('santo estevao', Decimal('19.20')),
#  ('montanha', Decimal('19.20')),
#  ('iguatu', Decimal('19.20')),
#  ('conselheiro pena', Decimal('19.20')),
#  ('santo antonio do jardim', Decimal('19.20')),
#  ('salesopolis', Decimal('19.20')),
#  ('lagoa dourada', Decimal('19.20')),
#  ('feira nova', Decimal('19.20')),
#  ('capinzal', Decimal('19.20')),
#  ('rio casca', Decimal('19.20')),
#  ('braco do norte', Decimal('19.20')),
#  ('assai', Decimal('19.20')),
#  ('ladario', Decimal('19.20')),
#  ('castilho', Decimal('19.20')),
#  ('bataguassu', Decimal('19.20')),
#  ('conceicao do rio verde', Decimal('19.20')),
#  ('colonia vitoria', Decimal('19.20')),
#  ('rio pardo de minas', Decimal('19.20')),
#  ('carmo do cajuru', Decimal('19.20')),
#  ('barra velha', Decimal('19.20')),
#  ('custodia', Decimal('19.20')),
#  ('iepe', Decimal('19.20')),
#  ('marechal floriano', Decimal('19.20')),
#  ('biritiba-mirim', Decimal('19.20')),
#  ('alexania', Decimal('19.20')),
#  ('otacilio costa', Decimal('19.20')),
#  ('brejo santo', Decimal('19.20')),
#  ('fartura', Decimal('19.20')),
#  ('sao romao', Decimal('19.20')),
#  ('pedra preta', Decimal('19.20')),
#  ('sao jose do ouro', Decimal('19.20')),
#  ('caldas', Decimal('19.20')),
#  ('elias fausto', Decimal('19.20')),
#  ('itai', Decimal('19.20')),
#  ('aguas da prata', Decimal('19.20')),
#  ('diamante do norte', Decimal('19.20')),
#  ('buriticupu', Decimal('19.20')),
#  ('carmopolis de minas', Decimal('19.20')),
#  ('livramento de nossa senhora', Decimal('19.20')),
#  ('paulo frontin', Decimal('19.20')),
#  ('sao jose do cedro', Decimal('19.20')),
#  ('duartina', Decimal('19.20')),
#  ('juara', Decimal('19.20')),
#  ('holambra ii', Decimal('19.20')),
#  ('aguas formosas', Decimal('19.20')),
#  ('severinia', Decimal('19.20')),
#  ('santo amaro', Decimal('19.20')),
#  ('iraquara', Decimal('19.20')),
#  ('miguel calmon', Decimal('19.20')),
#  ('cambuquira', Decimal('19.20')),
#  ('maracas', Decimal('19.20')),
#  ('mage', Decimal('19.17')),
#  ('cuiaba', Decimal('19.16')),
#  ('araxa', Decimal('19.16')),
#  ('luis eduardo magalhaes', Decimal('19.11')),
#  ('sertaozinho', Decimal('19.10')),
#  ('garanhuns', Decimal('19.10')),
#  ('guaiba', Decimal('19.10')),
#  ('santa barbara', Decimal('19.08')),
#  ('mafra', Decimal('19.08')),
#  ('jandira', Decimal('19.05')),
#  ('ibiruba', Decimal('19.05')),
#  ('paulista', Decimal('19.05')),
#  ('juquitiba', Decimal('19.05')),
#  ('castanhal', Decimal('19.05')),
#  ('simoes filho', Decimal('19.05')),
#  ('balneario camboriu', Decimal('19.04')),
#  ('goiania', Decimal('19.03')),
#  ('timoteo', Decimal('19.02')),
#  ('maringa', Decimal('19.00')),
#  ('guarapuava', Decimal('19.00')),
#  ('marialva', Decimal('19.00')),
#  ('santana do paraiso', Decimal('19.00')),
#  ('vicosa', Decimal('18.99')),
#  ('rio claro', Decimal('18.99')),
#  ('andradina', Decimal('18.98')),
#  ('americana', Decimal('18.97')),
#  ('petropolis', Decimal('18.96')),
#  ('carangola', Decimal('18.96')),
#  ('linhares', Decimal('18.95')),
#  ('nova odessa', Decimal('18.95')),
#  ('capao da canoa', Decimal('18.95')),
#  ('januaria', Decimal('18.91')),
#  ('porto feliz', Decimal('18.91')),
#  ('coxim', Decimal('18.91')),
#  ('itapipoca', Decimal('18.91')),
#  ('santa gertrudes', Decimal('18.91')),
#  ('paranapanema', Decimal('18.91')),
#  ('taquari', Decimal('18.91')),
#  ('cambui', Decimal('18.91')),
#  ('sao lourenco', Decimal('18.91')),
#  ('sombrio', Decimal('18.91')),
#  ('alvinopolis', Decimal('18.91')),
#  ('carandai', Decimal('18.91')),
#  ('pompeu', Decimal('18.91')),
#  ('ouroeste', Decimal('18.91')),
#  ('ipatinga', Decimal('18.90')),
#  ('valinhos', Decimal('18.89')),
#  ('limeira', Decimal('18.88')),
#  ('indaiatuba', Decimal('18.88')),
#  ('itapolis', Decimal('18.86')),
#  ('garca', Decimal('18.86')),
#  ('sao jose', Decimal('18.86')),
#  ('camboriu', Decimal('18.86')),
#  ('capao bonito', Decimal('18.86')),
#  ('santa maria', Decimal('18.84')),
#  ('joao pessoa', Decimal('18.83')),
#  ('bebedouro', Decimal('18.82')),
#  ('poa', Decimal('18.82')),
#  ('mococa', Decimal('18.82')),
#  ('leopoldina', Decimal('18.82')),
#  ('igrejinha', Decimal('18.82')),
#  ('balsas', Decimal('18.82')),
#  ('tucurui', Decimal('18.82')),
#  ('laranjal paulista', Decimal('18.82')),
#  ('porto alegre', Decimal('18.80')),
#  ('ponte nova', Decimal('18.80')),
#  ('sao joao de meriti', Decimal('18.79')),
#  ('sao joao da boa vista', Decimal('18.77')),
#  ('tupa', Decimal('18.77')),
#  ('ituverava', Decimal('18.76')),
#  ('sao carlos', Decimal('18.76')),
#  ('aracatuba', Decimal('18.76')),
#  ('arapiraca', Decimal('18.76')),
#  ('jundiai', Decimal('18.74')),
#  ('osorio', Decimal('18.74')),
#  ('resende', Decimal('18.74')),
#  ('santana de parnaiba', Decimal('18.73')),
#  ('videira', Decimal('18.72')),
#  ('araraquara', Decimal('18.70')),
#  ('florianopolis', Decimal('18.69')),
#  ('cerquilho', Decimal('18.67')),
#  ('sao roque', Decimal('18.67')),
#  ('pontal', Decimal('18.67')),
#  ('campo bom', Decimal('18.67')),
#  ('mangaratiba', Decimal('18.67')),
#  ('nova prata do iguacu', Decimal('18.67')),
#  ('santo amaro da imperatriz', Decimal('18.67')),
#  ('congonhas', Decimal('18.67')),
#  ('vitoria da conquista', Decimal('18.67')),
#  ('cerqueira cesar', Decimal('18.67')),
#  ('terra roxa', Decimal('18.67')),
#  ('itaobim', Decimal('18.67')),
#  ('rio novo do sul', Decimal('18.67')),
#  ('sao pedro', Decimal('18.67')),
#  ('tres de maio', Decimal('18.67')),
#  ('caldas novas', Decimal('18.67')),
#  ('agua boa', Decimal('18.67')),
#  ('raul soares', Decimal('18.67')),
#  ('monte alegre do sul', Decimal('18.67')),
#  ('jeceaba', Decimal('18.67')),
#  ('reboucas', Decimal('18.67')),
#  ('cachoeirinha', Decimal('18.67')),
#  ('vilhena', Decimal('18.67')),
#  ('fronteira', Decimal('18.67')),
#  ('assis chateaubriand', Decimal('18.67')),
#  ('iacanga', Decimal('18.67')),
#  ('mallet', Decimal('18.67')),
#  ('uruara', Decimal('18.67')),
#  ('piritiba', Decimal('18.67')),
#  ('sao jose da barra', Decimal('18.67')),
#  ('cachoeira alta', Decimal('18.67')),
#  ('seara', Decimal('18.67')),
#  ('fernando prestes', Decimal('18.67')),
#  ('pilar do sul', Decimal('18.67')),
#  ('flores da cunha', Decimal('18.67')),
#  ('mendes', Decimal('18.67')),
#  ('andradas', Decimal('18.67')),
#  ('pirai do sul', Decimal('18.67')),
#  ('camacan', Decimal('18.67')),
#  ('teixeiras', Decimal('18.67')),
#  ('pirapora', Decimal('18.67')),
#  ('catole do rocha', Decimal('18.67')),
#  ('itariri', Decimal('18.67')),
#  ('santa rita de caldas', Decimal('18.67')),
#  ('quatro barras', Decimal('18.67')),
#  ('rio pomba', Decimal('18.67')),
#  ('medina', Decimal('18.67')),
#  ('costa rica', Decimal('18.67')),
#  ('nova santa rita', Decimal('18.67')),
#  ('seabra', Decimal('18.67')),
#  ('santo antonio da platina', Decimal('18.67')),
#  ('engenheiro paulo de frontin', Decimal('18.67')),
#  ('jacunda', Decimal('18.67')),
#  ('sapucaia', Decimal('18.67')),
#  ("itapejara d'oeste", Decimal('18.67')),
#  ('santa isabel do para', Decimal('18.67')),
#  ('pacajus', Decimal('18.67')),
#  ('sao jose do calcado', Decimal('18.67')),
#  ('pombal', Decimal('18.67')),
#  ('mundo novo', Decimal('18.67')),
#  ('atibaia', Decimal('18.65')),
#  ('mogi-guacu', Decimal('18.64')),
#  ('guaruja', Decimal('18.64')),
#  ('votorantim', Decimal('18.64')),
#  ('viamao', Decimal('18.63')),
#  ('curvelo', Decimal('18.60')),
#  ('cacapava', Decimal('18.59')),
#  ('cajamar', Decimal('18.59')),
#  ('rio das ostras', Decimal('18.59')),
#  ('diadema', Decimal('18.59')),
#  ('campo largo', Decimal('18.59')),
#  ('mogi das cruzes', Decimal('18.58')),
#  ('santos', Decimal('18.58')),
#  ('navegantes', Decimal('18.58')),
#  ('ibiuna', Decimal('18.58')),
#  ('ouro preto', Decimal('18.57')),
#  ('niteroi', Decimal('18.56')),
#  ('mairinque', Decimal('18.56')),
#  ('curitiba', Decimal('18.55')),
#  ('sao jose do rio pardo', Decimal('18.55')),
#  ('guararapes', Decimal('18.53')),
#  ('itapeva', Decimal('18.53')),
#  ('campinas', Decimal('18.52')),
#  ('carapicuiba', Decimal('18.51')),
#  ('joao monlevade', Decimal('18.51')),
#  ('sao paulo', Decimal('18.50')),
#  ('muriae', Decimal('18.50')),
#  ('dourados', Decimal('18.50')),
#  ('araruama', Decimal('18.49')),
#  ('carmo', Decimal('18.46')),
#  ('cosmopolis', Decimal('18.46')),
#  ('loanda', Decimal('18.46')),
#  ('santa maria da vitoria', Decimal('18.46')),
#  ('mirandopolis', Decimal('18.46')),
#  ('frutal', Decimal('18.46')),
#  ('quissama', Decimal('18.46')),
#  ('paulo afonso', Decimal('18.46')),
#  ('viana', Decimal('18.46')),
#  ('jau', Decimal('18.41')),
#  ('barretos', Decimal('18.41')),
#  ('laranjeiras do sul', Decimal('18.40')),
#  ('cafelandia', Decimal('18.40')),
#  ('itajuba', Decimal('18.38')),
#  ('itaperuna', Decimal('18.38')),
#  ('duque de caxias', Decimal('18.37')),
#  ('ponta grossa', Decimal('18.37')),
#  ('macapa', Decimal('18.37')),
#  ('macae', Decimal('18.36')),
#  ('rio de janeiro', Decimal('18.35')),
#  ('itapevi', Decimal('18.35')),
#  ('juazeiro do norte', Decimal('18.35')),
#  ('formosa', Decimal('18.35')),
#  ('cabo frio', Decimal('18.34')),
#  ('ribeirao preto', Decimal('18.33')),
#  ('nova iguacu', Decimal('18.33')),
#  ('osasco', Decimal('18.33')),
#  ('bento goncalves', Decimal('18.33')),
#  ('uruguaiana', Decimal('18.33')),
#  ('ubatuba', Decimal('18.32')),
#  ('caratinga', Decimal('18.32')),
#  ('mogi mirim', Decimal('18.32')),
#  ('contagem', Decimal('18.31')),
#  ("santa barbara d'oeste", Decimal('18.31')),
#  ('ferraz de vasconcelos', Decimal('18.31')),
#  ('lavras', Decimal('18.31')),
#  ('belo horizonte', Decimal('18.29')),
#  ('campo grande', Decimal('18.29')),
#  ('quirinopolis', Decimal('18.29')),
#  ('sao jose do norte', Decimal('18.29')),
#  ('lages', Decimal('18.29')),
#  ('santa luzia', Decimal('18.29')),
#  ('almenara', Decimal('18.29')),
#  ('sao bento do sapucai', Decimal('18.29')),
#  ('campo mourao', Decimal('18.29')),
#  ('boituva', Decimal('18.29')),
#  ('rodeio', Decimal('18.29')),
#  ('bicas', Decimal('18.29')),
#  ('varzea grande', Decimal('18.29')),
#  ('itapuranga', Decimal('18.29')),
#  ('comendador levy gasparian', Decimal('18.29')),
#  ('pederneiras', Decimal('18.29')),
#  ('miguel pereira', Decimal('18.29')),
#  ('pirapetinga', Decimal('18.29')),
#  ('campo maior', Decimal('18.29')),
#  ('ruy barbosa', Decimal('18.29')),
#  ('lagoa formosa', Decimal('18.29')),
#  ('niquelandia', Decimal('18.29')),
#  ('esmeraldas', Decimal('18.29')),
#  ('cunha', Decimal('18.29')),
#  ('campinorte', Decimal('18.29')),
#  ('piedade de caratinga', Decimal('18.29')),
#  ('bady bassitt', Decimal('18.29')),
#  ('arceburgo', Decimal('18.29')),
#  ('tocantinopolis', Decimal('18.29')),
#  ('dois vizinhos', Decimal('18.29')),
#  ('chapadao do sul', Decimal('18.29')),
#  ('campo ere', Decimal('18.29')),
#  ('nazare paulista', Decimal('18.29')),
#  ('cruz', Decimal('18.29')),
#  ('porto real', Decimal('18.29')),
#  ...]

# %%
query = """with count_per_order as 
(select orders.order_id, orders.customer_id, count(order_items.order_id) as oc
from orders join order_items
on orders.order_id = order_items.order_id
group by orders.order_id, orders.customer_id)

select customers.customer_city, round(avg(count_per_order.oc),2) average_orders
from customers join count_per_order
on customers.customer_id = count_per_order.customer_id
group by customers.customer_city order by average_orders desc
"""


cur.execute(query)

data = cur.fetchall()
df = pd.DataFrame(data,columns = ["customer city", "average products/order"])
df.head(10)
# Out:
#         customer city average products/order
# 0      padre carvalho                 112.00
# 1         celso ramos                 104.00
# 2               datas                  96.00
# 3       candido godoi                  96.00
# 4      matias olimpio                  80.00
# 5          cidelandia                  64.00
# 6          curralinho                  64.00
# 7             picarra                  64.00
# 8  morro de sao paulo                  64.00
# 9     teixeira soares                  64.00

# %% [markdown]
# # 3. Calculate the percentage of total revenue contributed by each product category.

# %%
query = """select upper(products.product_category) category, 
round((sum(payments.payment_value)/(select sum(payment_value) from payments))*100,2) sales_percentage
from products join order_items 
on products.product_id = order_items.product_id
join payments 
on payments.order_id = order_items.order_id
group by category order by sales_percentage desc"""


cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data,columns = ["Category", "percentage distribution"])
df.head()
# Out:
#                Category  percentage distribution
# 0        BED TABLE BATH                   171.16
# 1         HEALTH BEAUTY                   165.65
# 2  COMPUTER ACCESSORIES                   158.45
# 3  FURNITURE DECORATION                   142.94
# 4       WATCHES PRESENT                   142.84

# %% [markdown]
# # Identify the correlation between product price and the number of times a product has been purchased.

# %%
import numpy as np
import pandas as pd
query = """select products.product_category, 
count(order_items.product_id),
round(avg(order_items.price),2)
from products join order_items
on products.product_id = order_items.product_id
group by products.product_category"""

cur = db.cursor()
cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data,columns = ["Category", "order_count","price"])

arr1 = df["order_count"]
arr2 = df["price"]

a = np.corrcoef([arr1,arr2])
print("the correlation is", a[0][-1])
# Out:
# the correlation is -0.10631514167157562

# %% [markdown]
# # Calculate the total revenue generated by each seller, and rank them by revenue.¶

# %%
query = """ select *, dense_rank() over(order by revenue desc) as rn from
(select order_items.seller_id, sum(payments.payment_value)
revenue from order_items join payments
on order_items.order_id = payments.order_id
group by order_items.seller_id) as a """

cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data, columns = ["seller_id", "revenue", "rank"])
df = df.head()
sns.barplot(x = "seller_id", y = "revenue", data = df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Calculate the moving average of order values for each customer over their order history.

# %%
query = """select customer_id, order_purchase_timestamp, payment,
avg(payment) over(partition by customer_id order by order_purchase_timestamp
rows between 2 preceding and current row) as mov_avg
from
(select orders.customer_id, orders.order_purchase_timestamp, 
payments.payment_value as payment
from payments join orders
on payments.order_id = orders.order_id) as a"""
cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data)
df
# Out:
#                                         0                    1       2  \
# 0        00012a2ce6f8dcda20d059ce98491703  2017-11-14 16:08:26  114.74
# 1        00012a2ce6f8dcda20d059ce98491703  2017-11-14 16:08:26  114.74
# 2        00012a2ce6f8dcda20d059ce98491703  2017-11-14 16:08:26  114.74
# 3        00012a2ce6f8dcda20d059ce98491703  2017-11-14 16:08:26  114.74
# 4        00012a2ce6f8dcda20d059ce98491703  2017-11-14 16:08:26  114.74
# ...                                   ...                  ...     ...
# 1662171  ffffe8b65bbe3087b653a978c870db99  2017-09-29 14:07:03   18.37
# 1662172  ffffe8b65bbe3087b653a978c870db99  2017-09-29 14:07:03   18.37
# 1662173  ffffe8b65bbe3087b653a978c870db99  2017-09-29 14:07:03   18.37
# 1662174  ffffe8b65bbe3087b653a978c870db99  2017-09-29 14:07:03   18.37
# 1662175  ffffe8b65bbe3087b653a978c870db99  2017-09-29 14:07:03   18.37
#
#                   3
# 0        114.739998
# 1        114.739998
# 2        114.739998
# 3        114.739998
# 4        114.739998
# ...             ...
# 1662171   18.370001
# 1662172   18.370001
# 1662173   18.370001
# 1662174   18.370001
# 1662175   18.370001
#
# [1662176 rows x 4 columns]

# %% [markdown]
# # Calculate the cumulative sales per month for each year.

# %%
query = """select years, months , payment, sum(payment)
over(order by years, months) cumulative_sales from 
(select year(orders.order_purchase_timestamp) as years,
month(orders.order_purchase_timestamp) as months,
round(sum(payments.payment_value),2) as payment from orders join payments
on orders.order_id = payments.order_id
group by years, months order by years, months) as a
"""
cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data)
df
# Out:
#        0   1            2             3
# 0   2016   9      4035.84  4.035840e+03
# 1   2016  10    945447.68  9.494835e+05
# 2   2016  12       313.92  9.497974e+05
# 3   2017   1   2215808.64  3.165606e+06
# 4   2017   2   4670528.15  7.836134e+06
# 5   2017   3   7197817.59  1.503395e+07
# 6   2017   4   6684608.47  2.171856e+07
# 7   2017   5   9486701.12  3.120526e+07
# 8   2017   6   8180422.09  3.938568e+07
# 9   2017   7   9478126.71  4.886381e+07
# 10  2017   8  10790341.12  5.965415e+07
# 11  2017   9  11644199.21  7.129835e+07
# 12  2017  10  12474846.08  8.377320e+07
# 13  2017  11  19118124.80  1.028913e+08
# 14  2017  12  14054423.68  1.169457e+08
# 15  2018   1  17840066.87  1.347858e+08
# 16  2018   2  15879413.44  1.506652e+08
# 17  2018   3  18554433.91  1.692197e+08
# 18  2018   4  18572567.69  1.877922e+08
# 19  2018   5  18463714.42  2.062559e+08
# 20  2018   6  16382088.01  2.226380e+08
# 21  2018   7  17064651.98  2.397027e+08
# 22  2018   8  16358805.14  2.560615e+08
# 23  2018   9     71032.64  2.561325e+08
# 24  2018  10      9434.72  2.561420e+08

# %% [markdown]
# # Calculate the year-over-year growth rate of total sales.¶

# %%
query = """with a as(select year(orders.order_purchase_timestamp) as years,
round(sum(payments.payment_value),2) as payment from orders join payments
on orders.order_id = payments.order_id
group by years order by years)

select years, ((payment - lag(payment, 1) over(order by years))/
lag(payment, 1) over(order by years)) * 100 from a"""

cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data, columns = ["years", "yoy % growth"])
df
# Out:
#    years  yoy % growth
# 0   2016           NaN
# 1   2017  12112.703758
# 2   2018     20.000924

# %% [markdown]
# # Calculate the retention rate of customers, defined as the percentage of customers who make another purchase within 6 months of their first purchase.

# %%
query = """with a as (select customers.customer_id,
min(orders.order_purchase_timestamp) first_order
from customers join orders
on customers.customer_id = orders.customer_id
group by customers.customer_id),

b as (select a.customer_id, count(distinct orders.order_purchase_timestamp) next_order
from a join orders
on orders.customer_id = a.customer_id
and orders.order_purchase_timestamp > first_order
and orders.order_purchase_timestamp < 
date_add(first_order, interval 6 month)
group by a.customer_id) 

select 100 * (count( distinct a.customer_id)/ count(distinct b.customer_id)) 
from a left join b 
on a.customer_id = b.customer_id ;"""

cur.execute(query)
data = cur.fetchall()

data
# Out:
# [(None,)]

# %% [markdown]
# # Identify the top 3 customers who spent the most money in each year.

# %%
query = """select years, customer_id, payment, d_rank
from
(select year(orders.order_purchase_timestamp) years,
orders.customer_id,
sum(payments.payment_value) payment,
dense_rank() over(partition by year(orders.order_purchase_timestamp)
order by sum(payments.payment_value) desc) d_rank
from orders join payments 
on payments.order_id = orders.order_id
group by year(orders.order_purchase_timestamp),
orders.customer_id) as a
where d_rank <= 3 ;"""

cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data, columns = ["years","id","payment","rank"])
sns.barplot(x = "id", y = "payment", data = df, hue = "years")
plt.xticks(rotation = 90)
plt.show()
